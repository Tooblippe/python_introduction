# %% [markdown]
# ## Data Analysis Using the Pandas Library
#
# <img src="../img/pandas.png" alt="Smiley face" height="150">

# %% [markdown]
# * pandas is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive
#
# * The two primary data structures of pandas
#  * Series (1-dimensional) and
#  * DataFrame (2-dimensional) __Think Spreadhseet, Timeseries__
#
# Handle the vast majority of typical use cases in finance, statistics, social science, and many areas of engineering.
#
# * For R users, DataFrame provides everything that R’s data.frame provides.
# * pandas is built on top of NumPy and is intended to integrate well within a scientific computing environment with many other 3rd party libraries.

# %%
# %pylab inline 
#set figure size
figsize(15, 6) 

from pandas import DataFrame, read_csv

import pandas as pd

Cape_Weather = DataFrame( read_csv('../data/CapeTown_2009_Temperatures.csv' ))

Cape_Weather
# Out:
# Populating the interactive namespace from numpy and matplotlib
#      high  low  radiation
# 0      25   16       29.0
# 1      23   15       25.7
# 2      25   15       21.5
# 3      26   16       15.2
# 4      26   17       10.8
# 5      26   17        9.1
# 6      25   17        9.7
# 7      25   17       12.5
# 8      23   16       17.5
# 9      25   15       22.4
# 10     30   16       27.3
# 11     26   15       29.1
# 12     25   17        NaN
# 13     23   16        NaN
# 14     25   12        NaN
# 15     23   17        NaN
# 16     21   17        NaN
# 17     23   17        NaN
# 18     27   17        NaN
# 19     30   16        NaN
# 20     26   16        NaN
# 21     23   15        NaN
# 22     25   15        NaN
# 23     25   15        NaN
# 24     25   17        NaN
# 25     25   17        NaN
# 26     21   15        NaN
# 27     27   13        NaN
# 28     25   16        NaN
# 29     25   17        NaN
# ..    ...  ...        ...
# 335    22   15        NaN
# 336    23   15        NaN
# 337    26   15        NaN
# 338    28   17        NaN
# 339    27   16        NaN
# 340    22   17        NaN
# 341    23   15        NaN
# 342    23   15        NaN
# 343    23   13        NaN
# 344    25   16        NaN
# 345    25   17        NaN
# 346    25   16        NaN
# 347    30   15        NaN
# 348    22   15        NaN
# 349    25   15        NaN
# 350    20   15        NaN
# 351    22   16        NaN
# 352    22   15        NaN
# 353    25   15        NaN
# 354    23   15        NaN
# 355    23   15        NaN
# 356    21   16        NaN
# 357    21   15        NaN
# 358    22   12        NaN
# 359    21   13        NaN
# 360    21   10        NaN
# 361    22   15        NaN
# 362    22   16        NaN
# 363    25   15        NaN
# 364    25   18        NaN
#
# [365 rows x 3 columns]

# %%
Cape_Weather['high'].head()  #plot

# %%
Cape_Weather.high.head(10)

# %%
#CustomPlot()
font_size = 24

title('Cape Town Temparature(2009)',fontsize = font_size)
xlabel('Day number',fontsize = font_size)
ylabel(r'Temperature [$^\circ C$] ',fontsize = font_size)

Cape_Weather.high.plot()
Cape_Weather.low.plot()
show()

# %%
#CustomPlot()
font_size = 24

title( 'Mean solar radiation(horisontal plane)', fontsize=font_size)
xlabel('Month Number', fontsize = font_size)
ylabel(r'$MJ / day / m^2$',fontsize = font_size)

Cape_Weather.radiation[0:11].plot()
show()

# %%
# lets look at a proxy for heating degree and cooling degree days

level = 25

print '>25 =', Cape_Weather[ Cape_Weather['high'] > level  ].count()['high']
print '<=25 =', Cape_Weather[ Cape_Weather['high'] <= level ].count()['high']
# Out:
# >25 = 59
# <=25 = 306

# %%
# Basic descriptive statistics
print Cape_Weather.describe()
# Out:
#              high         low  radiation
# count  365.000000  365.000000   12.00000
# mean    21.545205   12.290411   19.15000
# std      4.764943    3.738431    7.65156
# min     12.000000    3.000000    9.10000
# 25%     18.000000   10.000000   12.07500
# 50%     21.000000   12.000000   19.50000
# 75%     25.000000   15.000000   26.10000
# max     36.000000   21.000000   29.10000

# %%
Cape_Weather.boxplot()
# Out:
# /home/tobie/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.py:2625: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)
# {'boxes': [<matplotlib.lines.Line2D at 0xadb0bb2c>,
#   <matplotlib.lines.Line2D at 0xadb1026c>,
#   <matplotlib.lines.Line2D at 0xadd1d32c>],
#  'caps': [<matplotlib.lines.Line2D at 0xadb1f5ec>,
#   <matplotlib.lines.Line2D at 0xadb1f0ac>,
#   <matplotlib.lines.Line2D at 0xadb11cec>,
#   <matplotlib.lines.Line2D at 0xadd1838c>,
#   <matplotlib.lines.Line2D at 0xadd2532c>,
#   <matplotlib.lines.Line2D at 0xadd2586c>],
#  'fliers': [<matplotlib.lines.Line2D at 0xadb108ec>,
#   <matplotlib.lines.Line2D at 0xadd18e0c>,
#   <matplotlib.lines.Line2D at 0xadd2b30c>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xadb10f6c>,
#   <matplotlib.lines.Line2D at 0xadd188cc>,
#   <matplotlib.lines.Line2D at 0xadd25dac>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xadb0b22c>,
#   <matplotlib.lines.Line2D at 0xadb1fb2c>,
#   <matplotlib.lines.Line2D at 0xadb11d0c>,
#   <matplotlib.lines.Line2D at 0xadb1166c>,
#   <matplotlib.lines.Line2D at 0xadd1d88c>,
#   <matplotlib.lines.Line2D at 0xadd1ddcc>]}

# %%
Cape_Weather.high.hist(bins=50)

# %%
Cape_Weather[Cape_Weather.high > 20 ].plot()

# %%
Cape_Weather.shape
# Out:
# (365, 3)

# %%
Cape_Weather[0:31].to_clipboard()

# %%
df = pd.read_clipboard()

# %%
df

# %% [markdown]
# end..
